# %%
import numpy as np 
import pandas as pd

# %%
data_path = 'dataset/financial news market events dataset 2025/financial_news_events.json'

# %%
#convert json to dataframe
df = pd.read_json(data_path, lines=True)

# %%
df.shape
# Out:
# (3024, 12)

# %%
df.head(30)
# Out:
#          Date                                           Headline  \
# 0  2025-05-21        Nikkei 225 index benefits from a weaker yen
# 1  2025-05-18  Government subsidy program gives a lift to the...
# 2  2025-06-25  New housing data release shows a slowdown in m...
# 3  2025-07-21  Massive stock buyback program announced by a c...
# 4  2025-07-23  Government spending bill is expected to stimul...
# 5  2025-03-18  Central bank maintains status quo on interest ...
# 6  2025-03-02  Tech Giant's New Product Launch Sparks Sector-...
# 7  2025-04-05  A massive data breach sends a tech company's s...
# 8  2025-04-08                                               None
# 9  2025-06-18  Market sentiment turns positive on vaccine tri...
# 10 2025-07-17  Global trade talks collapse, causing market tu...
# 11 2025-05-28  Aerospace and Defense sector sees rally amid g...
# 12 2025-04-28  Supply chain issues impact manufacturing secto...
# ...

# %%
#unique sector
df['Sector'].nunique()
# Out:
# 18

# %%
print(df['Sector'].unique())
# Out:
# ['Technology' 'Retail' 'Consumer Goods' 'Transportation'
#  'Telecommunications' 'Automotive' 'Energy' 'Pharmaceuticals' 'Healthcare'
#  'Aerospace & Defense' 'Finance' 'Industrials' 'Real Estate' 'Agriculture'
#  'Utilities' 'Construction' 'Media & Entertainment' 'Materials']
